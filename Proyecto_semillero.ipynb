# %% [markdown]
# <a href="https://colab.research.google.com/github/LuchoValr/Semillero/blob/main/Proyecto_semillero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#Pais, tipo de relacion, año y valor

# %% [markdown]
# ##Exportaciones por pais

# %%
ex_p = pd.read_table('https://raw.githubusercontent.com/LuchoValr/Semillero/main/Datos/exportaciones%20por%20pais.txt')
ex_p.rename(columns={'Valor exportado en 2001':'2001','Valor exportado en 2002':'2002','Valor exportado en 2003':'2003','Valor exportado en 2004':'2004','Valor exportado en 2005':'2005','Valor exportado en 2006':'2006','Valor exportado en 2007':'2007','Valor exportado en 2008':'2008','Valor exportado en 2009':'2009','Valor exportado en 2010':'2010','Valor exportado en 2011':'2011','Valor exportado en 2012':'2012','Valor exportado en 2013':'2013','Valor exportado en 2014':'2014','Valor exportado en 2015':'2015','Valor exportado en 2016':'2016','Valor exportado en 2017':'2017','Valor exportado en 2018':'2018','Valor exportado en 2019':'2019','Valor exportado en 2020':'2020'})
# Out:
#                   Importadores      2001      2002      2003      2004  \
# 0                        Mundo  12301486  11897488  13092218  16729678
# 1    Estados Unidos de América   5344533   5328470   6160245   7042201
# 2                        China     19907     27825     82204    137504
# 3                       Panamá    265163    214697    170524    216490
# 4                      Ecuador    699929    811559    778966   1010665
# ..                         ...       ...       ...       ...       ...
# 223                Timor-Leste         0         0         0         0
# 224                 Seychelles         0         0         0         7
# 225      Sudán (antes de 2012)        77        25         0        23
# 226                 Uzbekistán         0         6         3         0
# 227                      Samoa         9         8         0         0
#
#          2005      2006      2007      2008      2009  ...      2012  \
# ...

# %%
pais_ex = ex_p.filter(['Importadores'])

# %% [markdown]
# ##Importaciones por pais

# %%
im_p = pd.read_table('https://raw.githubusercontent.com/LuchoValr/Semillero/main/Datos/importaciones%20por%20pais.txt')
im_p.rename(columns={'Valor importado en 2001':'2001','Valor importado en 2002':'2002','Valor importado en 2003':'2003','Valor importado en 2004':'2004','Valor importado en 2005':'2005','Valor importado en 2006':'2006','Valor importado en 2007':'2007','Valor importado en 2008':'2008','Valor importado en 2009':'2009','Valor importado en 2010':'2010','Valor importado en 2011':'2011','Valor importado en 2012':'2012','Valor importado en 2013':'2013','Valor importado en 2014':'2014','Valor importado en 2015':'2015','Valor importado en 2016':'2016','Valor importado en 2017':'2017','Valor importado en 2018':'2018','Valor importado en 2019':'2019','Valor importado en 2020':'2020'})
# Out:
#                   Exportadores      2001      2002      2003      2004  \
# 0                        Mundo  12820352  12689965  13880613  17099537
# 1    Estados Unidos de América   4442775   4051198   4112710   4806760
# 2                        China    475405    532847    688673   1244730
# 3                       México    596168    677990    744375    935642
# 4                       Brasil    582060    642840    769003   1352172
# ..                         ...       ...       ...       ...       ...
# 222       Islas Turks y Caicos         5         1         0         0
# 223               Burkina Faso     15335     18637     14619      4428
# 224                      Samoa         0         5         0         6
# 225                      Yemen         0         0         0         0
# 226                     Zambia        44         0         0         0
#
#          2005      2006      2007      2008      2009  ...      2012  \
# ...

# %%
pais_im = im_p.filter(['Exportadores'])

# %% [markdown]
# ##Filtrando paises

# %%
paises = pais_ex.join(pais_im)
paises2=paises.drop([0])
paises.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Importadores  228 non-null    object
#  1   Exportadores  227 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
paises2
# Out:
#                   Importadores               Exportadores
# 1    Estados Unidos de América  Estados Unidos de América
# 2                        China                      China
# 3                       Panamá                     México
# 4                      Ecuador                     Brasil
# 5                       Brasil                   Alemania
# ..                         ...                        ...
# 223                Timor-Leste               Burkina Faso
# 224                 Seychelles                      Samoa
# 225      Sudán (antes de 2012)                      Yemen
# 226                 Uzbekistán                     Zambia
# 227                      Samoa                        NaN
#
# [227 rows x 2 columns]

# %% [markdown]
# ###Encontrando Duplicados

# %%
paises3 = pd.concat([paises2['Exportadores'], paises2['Importadores']], axis = 0).reset_index()
paises4 = paises3.rename(columns={0:'Paises'})
paises5 = paises4.drop(['index'], axis=1)

paises5
# Out:
#                         Paises
# 0    Estados Unidos de América
# 1                        China
# 2                       México
# 3                       Brasil
# 4                     Alemania
# ..                         ...
# 449                Timor-Leste
# 450                 Seychelles
# 451      Sudán (antes de 2012)
# 452                 Uzbekistán
# 453                      Samoa
#
# [454 rows x 1 columns]

# %%
paises5.Paises.value_counts().reset_index()
# Out:
#                                         index  Paises
# 0                   Estados Unidos de América       2
# 1                                Macao, China       2
# 2                                     Tokelau       2
# 3                                     Armenia       2
# 4                                       Nepal       2
# ..                                        ...     ...
# 225              San Martin (parte Holandesa)       1
# 226  Tierras Australes y Antárticas Francesas       1
# 227               Rancho de naves y aeronaves       1
# 228                                    Lesoto       1
# 229                      San Pedro y Miquelón       1
#
# [230 rows x 2 columns]

# %%
paises6 = paises5.drop_duplicates()
paises7 = paises6.drop([226],axis=0)
paises8 = paises7.reset_index(drop=True)


paises8
# Out:
#                            Paises
# 0       Estados Unidos de América
# 1                           China
# 2                          México
# 3                          Brasil
# 4                        Alemania
# ..                            ...
# 225                        Zambia
# 226  Bonaire, San Estaquio y Saba
# 227  San Martin (parte Holandesa)
# 228                  Isla Norfolk
# 229          San Pedro y Miquelón
#
# [230 rows x 1 columns]

# %% [markdown]
# ###Asignando tipo de relacion
